# %% [markdown]
# # MRI Classification Using PyTorch

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_auc_score, roc_curve
from torchvision.datasets import ImageFolder
import seaborn as sns
import shutil
import json
import gc

LEARNING_RATE = 0.00001
WEIGHT_DECAY = 0.0001
BATCH_SIZE = 8
DROPOUT_RATE = 0.4
PRETRAINED_WEIGHTS = True

NUM_EPOCHS = 20
PATIENCE = 5

# %% [markdown]
# ## Data Preparation
# Load the dataset and split it into training and validation sets, starting with first fold generated by data_preparation.ipynb

# %%
with open('mean_std.json', 'r') as f:
    mean_std = json.load(f)

mean = mean_std['mean']
std = mean_std['std']

transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(30),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
])

# Load data for fold 0
k_folds = 5
base_dir = 'dataset_kfold'
fold = 0
train_dir = os.path.join(base_dir, f'fold_{fold}', 'train')
val_dir = os.path.join(base_dir, f'fold_{fold}', 'val')
fold += 1

train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
val_dataset = datasets.ImageFolder(root=val_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# ## Define the Model

# %%
# Define the ResNet model
class SimpleResNet(nn.Module):
    def __init__(self, num_classes):
        super(SimpleResNet, self).__init__()
        self.model = models.resnet50(pretrained=PRETRAINED_WEIGHTS)
        self.model.fc = nn.Sequential(
            nn.Dropout(DROPOUT_RATE),
            nn.Linear(self.model.fc.in_features, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# Instantiate the model
num_classes = len(train_dataset.classes)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleResNet(num_classes=num_classes).to(device)

# %%
# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# %%
def train(model, device, train_loader, criterion, optimizer, epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100. * correct / total
    print(f'Epoch {epoch}, Loss: {epoch_loss:.4f}, Accuracy: {accuracy:.2f}%')
    return epoch_loss, accuracy

# Define the validation function
def validate(model, device, val_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for data, target in val_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            val_loss += criterion(output, target).item()
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(target.cpu().numpy())
            all_probs.extend(torch.softmax(output, dim=1).cpu().numpy())  # Get probabilities

    val_loss /= len(val_loader)
    accuracy = 100. * correct / total
    print(f'Validation Loss: {val_loss:.4f}, Accuracy: {accuracy:.2f}%')
    return val_loss, accuracy, all_preds, all_labels, all_probs

# %% [markdown]
# ## Start training the model

# %%
# Training and validation loop with early stopping
num_epochs = NUM_EPOCHS
patience = PATIENCE
best_val_loss = float('inf')
epochs_no_improve = 0

train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
all_preds = []
all_labels = []
all_probs = []  # To store the probabilities for AUC-ROC

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, device, train_loader, criterion, optimizer, epoch)
    val_loss, val_acc, preds, labels, probs = validate(model, device, val_loader, criterion)
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)
    all_preds.extend(preds)
    all_labels.extend(labels)
    all_probs.extend(probs)
    
    print(f'Epoch {epoch+1}/{num_epochs} - '
          f'Train loss: {train_loss:.4f}, Train accuracy: {train_acc:.4f} - '
          f'Val loss: {val_loss:.4f}, Val accuracy: {val_acc:.4f}')
    
    # Check for early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1

    if epochs_no_improve == patience:
        print('Early stopping!')
        break

# Calculate AUC-ROC
all_probs = np.array(all_probs)  # Convert to numpy array
auc_roc = roc_auc_score(all_labels, all_probs, multi_class='ovr', average=None)
for i, class_auc in enumerate(auc_roc):
    print(f"AUC-ROC for class {val_dataset.classes[i]}: {class_auc:.4f}")

# Save the last epoch model
torch.save(model.state_dict(), 'resn_saved.pth')
print("Model saved as resn_saved.pth")
# Out:
# Epoch 0, Loss: 1.2777, Accuracy: 41.67%
# Validation Loss: 1.0951, Accuracy: 68.75%
# Epoch 1/20 - Train loss: 1.2777, Train accuracy: 41.6667 - Val loss: 1.0951, Val accuracy: 68.7500
# Epoch 1, Loss: 1.0204, Accuracy: 65.10%
# Validation Loss: 0.7338, Accuracy: 85.42%
# Epoch 2/20 - Train loss: 1.0204, Train accuracy: 65.1042 - Val loss: 0.7338, Val accuracy: 85.4167
# Epoch 2, Loss: 0.8197, Accuracy: 74.22%
# Validation Loss: 0.5798, Accuracy: 81.25%
# Epoch 3/20 - Train loss: 0.8197, Train accuracy: 74.2188 - Val loss: 0.5798, Val accuracy: 81.2500
# Epoch 3, Loss: 0.6925, Accuracy: 75.78%
# Validation Loss: 0.4452, Accuracy: 87.50%
# Epoch 4/20 - Train loss: 0.6925, Train accuracy: 75.7812 - Val loss: 0.4452, Val accuracy: 87.5000
# Epoch 4, Loss: 0.5750, Accuracy: 80.21%
# Validation Loss: 0.3460, Accuracy: 91.67%
# Epoch 5/20 - Train loss: 0.5750, Train accuracy: 80.2083 - Val loss: 0.3460, Val accuracy: 91.6667
# Epoch 5, Loss: 0.5158, Accuracy: 82.81%
# Validation Loss: 0.3447, Accuracy: 90.62%
# Epoch 6/20 - Train loss: 0.5158, Train accuracy: 82.8125 - Val loss: 0.3447, Val accuracy: 90.6250
# Epoch 6, Loss: 0.4992, Accuracy: 84.38%
# Validation Loss: 0.2939, Accuracy: 93.75%
# Epoch 7/20 - Train loss: 0.4992, Train accuracy: 84.3750 - Val loss: 0.2939, Val accuracy: 93.7500
# Epoch 7, Loss: 0.4269, Accuracy: 85.42%
# Validation Loss: 0.2863, Accuracy: 90.62%
# Epoch 8/20 - Train loss: 0.4269, Train accuracy: 85.4167 - Val loss: 0.2863, Val accuracy: 90.6250
# Epoch 8, Loss: 0.3774, Accuracy: 88.80%
# Validation Loss: 0.2602, Accuracy: 93.75%
# Epoch 9/20 - Train loss: 0.3774, Train accuracy: 88.8021 - Val loss: 0.2602, Val accuracy: 93.7500
# Epoch 9, Loss: 0.3003, Accuracy: 93.23%
# Validation Loss: 0.1981, Accuracy: 94.79%
# Epoch 10/20 - Train loss: 0.3003, Train accuracy: 93.2292 - Val loss: 0.1981, Val accuracy: 94.7917
# Epoch 10, Loss: 0.3519, Accuracy: 90.89%
# Validation Loss: 0.1673, Accuracy: 96.88%
# Epoch 11/20 - Train loss: 0.3519, Train accuracy: 90.8854 - Val loss: 0.1673, Val accuracy: 96.8750
# Epoch 11, Loss: 0.2475, Accuracy: 92.71%
# Validation Loss: 0.1524, Accuracy: 95.83%
# Epoch 12/20 - Train loss: 0.2475, Train accuracy: 92.7083 - Val loss: 0.1524, Val accuracy: 95.8333
# Epoch 12, Loss: 0.2367, Accuracy: 93.23%
# Validation Loss: 0.1485, Accuracy: 96.88%
# Epoch 13/20 - Train loss: 0.2367, Train accuracy: 93.2292 - Val loss: 0.1485, Val accuracy: 96.8750
# Epoch 13, Loss: 0.2148, Accuracy: 92.97%
# Validation Loss: 0.1340, Accuracy: 96.88%
# Epoch 14/20 - Train loss: 0.2148, Train accuracy: 92.9688 - Val loss: 0.1340, Val accuracy: 96.8750
# Epoch 14, Loss: 0.2021, Accuracy: 95.05%
# Validation Loss: 0.1121, Accuracy: 95.83%
# Epoch 15/20 - Train loss: 0.2021, Train accuracy: 95.0521 - Val loss: 0.1121, Val accuracy: 95.8333
# Epoch 15, Loss: 0.2158, Accuracy: 93.23%
# Validation Loss: 0.1428, Accuracy: 95.83%
# Epoch 16/20 - Train loss: 0.2158, Train accuracy: 93.2292 - Val loss: 0.1428, Val accuracy: 95.8333
# Epoch 16, Loss: 0.1763, Accuracy: 95.31%
# Validation Loss: 0.1492, Accuracy: 95.83%
# Epoch 17/20 - Train loss: 0.1763, Train accuracy: 95.3125 - Val loss: 0.1492, Val accuracy: 95.8333
# Epoch 17, Loss: 0.1745, Accuracy: 96.61%
# Validation Loss: 0.1499, Accuracy: 93.75%
# Epoch 18/20 - Train loss: 0.1745, Train accuracy: 96.6146 - Val loss: 0.1499, Val accuracy: 93.7500
# Epoch 18, Loss: 0.1834, Accuracy: 94.27%
# Validation Loss: 0.0677, Accuracy: 100.00%
# Epoch 19/20 - Train loss: 0.1834, Train accuracy: 94.2708 - Val loss: 0.0677, Val accuracy: 100.0000
# Epoch 19, Loss: 0.1695, Accuracy: 95.05%
# Validation Loss: 0.1016, Accuracy: 95.83%
# Epoch 20/20 - Train loss: 0.1695, Train accuracy: 95.0521 - Val loss: 0.1016, Val accuracy: 95.8333
# AUC-ROC for class glioma: 0.9968
# AUC-ROC for class meningioma: 0.9738
# AUC-ROC for class notumor: 0.9947
# AUC-ROC for class pituitary: 0.9906
# Model saved as resn_saved.pth

# %% [markdown]
# ## Visualize

# %%
# Plotting the results
actual_epochs = range(1, epoch + 2)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(actual_epochs, train_losses, 'b', label='Training loss')
plt.plot(actual_epochs, val_losses, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(actual_epochs, train_accuracies, 'b', label='Training accuracy')
plt.plot(actual_epochs, val_accuracies, 'r', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Compute the confusion matrix
conf_matrix = confusion_matrix(all_labels, all_preds, labels=list(range(num_classes)))

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=val_dataset.classes)
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ## Remaining k-fold, train and visualize

# %%
fold_results = []

# Loop over each fold
for f in range(1, k_folds):
    print(f'Fold {f + 1}/{k_folds}')

    # Load data for fold
    train_dir = os.path.join(base_dir, f'fold_{f}', 'train')
    val_dir = os.path.join(base_dir, f'fold_{f}', 'val')

    train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
    val_dataset = datasets.ImageFolder(root=val_dir, transform=transform)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

    # Set device and model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = SimpleResNet(num_classes=num_classes).to(device)

    # Optimizer and criterion
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    criterion = nn.CrossEntropyLoss()

    # Early stopping parameters
    num_epochs = NUM_EPOCHS
    patience = PATIENCE
    best_val_loss = float('inf')
    epochs_no_improve = 0

    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []
    all_preds = []
    all_labels = []
    all_probs = []

    # Training loop with early stopping
    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, device, train_loader, criterion, optimizer, epoch)
        val_loss, val_acc, preds, labels, probs = validate(model, device, val_loader, criterion)
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)
        all_preds.extend(preds)
        all_labels.extend(labels)
        all_probs.extend(probs)

        print(f'Epoch {epoch+1}/{num_epochs} - '
              f'Train loss: {train_loss:.4f}, Train accuracy: {train_acc:.4f} - '
              f'Val loss: {val_loss:.4f}, Val accuracy: {val_acc:.4f}')

        # Check for early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve == patience:
            print('Early stopping!')
            break

    all_probs = np.array(all_probs)
    auc_roc = roc_auc_score(all_labels, all_probs, multi_class='ovr', average=None)
    
    # Store fold results
    fold_results.append({
        'fold': f,
        'train_losses': train_losses,
        'train_accuracies': train_accuracies,
        'val_losses': val_losses,
        'val_accuracies': val_accuracies,
        'best_val_loss': best_val_loss,
        'conf_matrix': conf_matrix,
        'val_true_classes': all_labels,
        'val_predictions': all_preds,
        'auc_roc': auc_roc
    })

    # Free CUDA memory after training
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# Fold 2/5
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0, Loss: 1.2791, Accuracy: 39.06%
# Validation Loss: 1.1447, Accuracy: 63.54%
# Epoch 1/20 - Train loss: 1.2791, Train accuracy: 39.0625 - Val loss: 1.1447, Val accuracy: 63.5417
# Epoch 1, Loss: 0.9789, Accuracy: 66.41%
# Validation Loss: 0.9091, Accuracy: 71.88%
# Epoch 2/20 - Train loss: 0.9789, Train accuracy: 66.4062 - Val loss: 0.9091, Val accuracy: 71.8750
# Epoch 2, Loss: 0.8009, Accuracy: 76.82%
# Validation Loss: 0.7419, Accuracy: 82.29%
# Epoch 3/20 - Train loss: 0.8009, Train accuracy: 76.8229 - Val loss: 0.7419, Val accuracy: 82.2917
# Epoch 3, Loss: 0.6829, Accuracy: 77.60%
# Validation Loss: 0.6267, Accuracy: 81.25%
# Epoch 4/20 - Train loss: 0.6829, Train accuracy: 77.6042 - Val loss: 0.6267, Val accuracy: 81.2500
# Epoch 4, Loss: 0.5634, Accuracy: 82.81%
# Validation Loss: 0.5776, Accuracy: 81.25%
# Epoch 5/20 - Train loss: 0.5634, Train accuracy: 82.8125 - Val loss: 0.5776, Val accuracy: 81.2500
# Epoch 5, Loss: 0.4814, Accuracy: 84.11%
# Validation Loss: 0.4972, Accuracy: 84.38%
# Epoch 6/20 - Train loss: 0.4814, Train accuracy: 84.1146 - Val loss: 0.4972, Val accuracy: 84.3750
# Epoch 6, Loss: 0.3927, Accuracy: 88.28%
# Validation Loss: 0.4838, Accuracy: 83.33%
# Epoch 7/20 - Train loss: 0.3927, Train accuracy: 88.2812 - Val loss: 0.4838, Val accuracy: 83.3333
# Epoch 7, Loss: 0.3619, Accuracy: 90.62%
# Validation Loss: 0.4237, Accuracy: 89.58%
# Epoch 8/20 - Train loss: 0.3619, Train accuracy: 90.6250 - Val loss: 0.4237, Val accuracy: 89.5833
# Epoch 8, Loss: 0.3453, Accuracy: 89.84%
# Validation Loss: 0.4477, Accuracy: 87.50%
# Epoch 9/20 - Train loss: 0.3453, Train accuracy: 89.8438 - Val loss: 0.4477, Val accuracy: 87.5000
# Epoch 9, Loss: 0.2731, Accuracy: 92.19%
# Validation Loss: 0.4193, Accuracy: 87.50%
# Epoch 10/20 - Train loss: 0.2731, Train accuracy: 92.1875 - Val loss: 0.4193, Val accuracy: 87.5000
# Epoch 10, Loss: 0.2526, Accuracy: 91.67%
# Validation Loss: 0.3895, Accuracy: 88.54%
# Epoch 11/20 - Train loss: 0.2526, Train accuracy: 91.6667 - Val loss: 0.3895, Val accuracy: 88.5417
# Epoch 11, Loss: 0.2649, Accuracy: 91.15%
# Validation Loss: 0.3735, Accuracy: 88.54%
# Epoch 12/20 - Train loss: 0.2649, Train accuracy: 91.1458 - Val loss: 0.3735, Val accuracy: 88.5417
# Epoch 12, Loss: 0.2228, Accuracy: 93.23%
# Validation Loss: 0.4067, Accuracy: 89.58%
# Epoch 13/20 - Train loss: 0.2228, Train accuracy: 93.2292 - Val loss: 0.4067, Val accuracy: 89.5833
# Epoch 13, Loss: 0.2064, Accuracy: 93.75%
# Validation Loss: 0.4459, Accuracy: 90.62%
# Epoch 14/20 - Train loss: 0.2064, Train accuracy: 93.7500 - Val loss: 0.4459, Val accuracy: 90.6250
# Epoch 14, Loss: 0.1697, Accuracy: 95.05%
# Validation Loss: 0.3824, Accuracy: 90.62%
# Epoch 15/20 - Train loss: 0.1697, Train accuracy: 95.0521 - Val loss: 0.3824, Val accuracy: 90.6250
# Epoch 15, Loss: 0.1731, Accuracy: 95.05%
# Validation Loss: 0.3987, Accuracy: 90.62%
# Epoch 16/20 - Train loss: 0.1731, Train accuracy: 95.0521 - Val loss: 0.3987, Val accuracy: 90.6250
# Epoch 16, Loss: 0.1414, Accuracy: 96.61%
# Validation Loss: 0.4040, Accuracy: 88.54%
# Epoch 17/20 - Train loss: 0.1414, Train accuracy: 96.6146 - Val loss: 0.4040, Val accuracy: 88.5417
# Early stopping!
# Fold 3/5
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0, Loss: 1.2758, Accuracy: 45.31%
# Validation Loss: 1.0954, Accuracy: 71.88%
# Epoch 1/20 - Train loss: 1.2758, Train accuracy: 45.3125 - Val loss: 1.0954, Val accuracy: 71.8750
# Epoch 1, Loss: 0.9861, Accuracy: 65.89%
# Validation Loss: 0.8181, Accuracy: 79.17%
# Epoch 2/20 - Train loss: 0.9861, Train accuracy: 65.8854 - Val loss: 0.8181, Val accuracy: 79.1667
# Epoch 2, Loss: 0.8008, Accuracy: 75.26%
# Validation Loss: 0.6651, Accuracy: 75.00%
# Epoch 3/20 - Train loss: 0.8008, Train accuracy: 75.2604 - Val loss: 0.6651, Val accuracy: 75.0000
# Epoch 3, Loss: 0.6392, Accuracy: 79.43%
# Validation Loss: 0.4994, Accuracy: 84.38%
# Epoch 4/20 - Train loss: 0.6392, Train accuracy: 79.4271 - Val loss: 0.4994, Val accuracy: 84.3750
# Epoch 4, Loss: 0.5372, Accuracy: 84.90%
# Validation Loss: 0.4158, Accuracy: 86.46%
# Epoch 5/20 - Train loss: 0.5372, Train accuracy: 84.8958 - Val loss: 0.4158, Val accuracy: 86.4583
# Epoch 5, Loss: 0.4319, Accuracy: 86.98%
# Validation Loss: 0.4255, Accuracy: 84.38%
# Epoch 6/20 - Train loss: 0.4319, Train accuracy: 86.9792 - Val loss: 0.4255, Val accuracy: 84.3750
# Epoch 6, Loss: 0.4003, Accuracy: 86.72%
# Validation Loss: 0.4005, Accuracy: 84.38%
# Epoch 7/20 - Train loss: 0.4003, Train accuracy: 86.7188 - Val loss: 0.4005, Val accuracy: 84.3750
# Epoch 7, Loss: 0.3630, Accuracy: 89.06%
# Validation Loss: 0.3105, Accuracy: 90.62%
# Epoch 8/20 - Train loss: 0.3630, Train accuracy: 89.0625 - Val loss: 0.3105, Val accuracy: 90.6250
# Epoch 8, Loss: 0.3725, Accuracy: 88.80%
# Validation Loss: 0.3755, Accuracy: 83.33%
# Epoch 9/20 - Train loss: 0.3725, Train accuracy: 88.8021 - Val loss: 0.3755, Val accuracy: 83.3333
# Epoch 9, Loss: 0.2972, Accuracy: 91.15%
# Validation Loss: 0.3461, Accuracy: 85.42%
# Epoch 10/20 - Train loss: 0.2972, Train accuracy: 91.1458 - Val loss: 0.3461, Val accuracy: 85.4167
# Epoch 10, Loss: 0.3076, Accuracy: 90.89%
# Validation Loss: 0.3261, Accuracy: 87.50%
# Epoch 11/20 - Train loss: 0.3076, Train accuracy: 90.8854 - Val loss: 0.3261, Val accuracy: 87.5000
# Epoch 11, Loss: 0.2926, Accuracy: 90.62%
# Validation Loss: 0.3725, Accuracy: 88.54%
# Epoch 12/20 - Train loss: 0.2926, Train accuracy: 90.6250 - Val loss: 0.3725, Val accuracy: 88.5417
# Epoch 12, Loss: 0.3016, Accuracy: 91.15%
# Validation Loss: 0.2587, Accuracy: 91.67%
# Epoch 13/20 - Train loss: 0.3016, Train accuracy: 91.1458 - Val loss: 0.2587, Val accuracy: 91.6667
# Epoch 13, Loss: 0.2452, Accuracy: 92.71%
# Validation Loss: 0.2975, Accuracy: 90.62%
# Epoch 14/20 - Train loss: 0.2452, Train accuracy: 92.7083 - Val loss: 0.2975, Val accuracy: 90.6250
# Epoch 14, Loss: 0.1875, Accuracy: 95.83%
# Validation Loss: 0.2426, Accuracy: 90.62%
# Epoch 15/20 - Train loss: 0.1875, Train accuracy: 95.8333 - Val loss: 0.2426, Val accuracy: 90.6250
# Epoch 15, Loss: 0.2092, Accuracy: 94.27%
# Validation Loss: 0.2566, Accuracy: 93.75%
# Epoch 16/20 - Train loss: 0.2092, Train accuracy: 94.2708 - Val loss: 0.2566, Val accuracy: 93.7500
# Epoch 16, Loss: 0.1803, Accuracy: 93.75%
# Validation Loss: 0.2527, Accuracy: 87.50%
# Epoch 17/20 - Train loss: 0.1803, Train accuracy: 93.7500 - Val loss: 0.2527, Val accuracy: 87.5000
# Epoch 17, Loss: 0.1783, Accuracy: 93.23%
# Validation Loss: 0.2351, Accuracy: 90.62%
# Epoch 18/20 - Train loss: 0.1783, Train accuracy: 93.2292 - Val loss: 0.2351, Val accuracy: 90.6250
# Epoch 18, Loss: 0.1079, Accuracy: 98.18%
# Validation Loss: 0.2417, Accuracy: 90.62%
# Epoch 19/20 - Train loss: 0.1079, Train accuracy: 98.1771 - Val loss: 0.2417, Val accuracy: 90.6250
# Epoch 19, Loss: 0.1150, Accuracy: 97.66%
# Validation Loss: 0.3217, Accuracy: 89.58%
# Epoch 20/20 - Train loss: 0.1150, Train accuracy: 97.6562 - Val loss: 0.3217, Val accuracy: 89.5833
# Fold 4/5
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0, Loss: 1.2572, Accuracy: 44.79%
# Validation Loss: 1.1088, Accuracy: 66.67%
# Epoch 1/20 - Train loss: 1.2572, Train accuracy: 44.7917 - Val loss: 1.1088, Val accuracy: 66.6667
# Epoch 1, Loss: 0.9921, Accuracy: 66.15%
# Validation Loss: 0.8150, Accuracy: 73.96%
# Epoch 2/20 - Train loss: 0.9921, Train accuracy: 66.1458 - Val loss: 0.8150, Val accuracy: 73.9583
# Epoch 2, Loss: 0.7814, Accuracy: 74.74%
# Validation Loss: 0.6598, Accuracy: 78.12%
# Epoch 3/20 - Train loss: 0.7814, Train accuracy: 74.7396 - Val loss: 0.6598, Val accuracy: 78.1250
# Epoch 3, Loss: 0.6819, Accuracy: 76.30%
# Validation Loss: 0.5303, Accuracy: 83.33%
# Epoch 4/20 - Train loss: 0.6819, Train accuracy: 76.3021 - Val loss: 0.5303, Val accuracy: 83.3333
# Epoch 4, Loss: 0.5808, Accuracy: 80.47%
# Validation Loss: 0.4413, Accuracy: 85.42%
# Epoch 5/20 - Train loss: 0.5808, Train accuracy: 80.4688 - Val loss: 0.4413, Val accuracy: 85.4167
# Epoch 5, Loss: 0.5070, Accuracy: 83.07%
# Validation Loss: 0.3974, Accuracy: 84.38%
# Epoch 6/20 - Train loss: 0.5070, Train accuracy: 83.0729 - Val loss: 0.3974, Val accuracy: 84.3750
# Epoch 6, Loss: 0.4271, Accuracy: 87.24%
# Validation Loss: 0.3808, Accuracy: 85.42%
# Epoch 7/20 - Train loss: 0.4271, Train accuracy: 87.2396 - Val loss: 0.3808, Val accuracy: 85.4167
# Epoch 7, Loss: 0.4037, Accuracy: 86.98%
# Validation Loss: 0.3558, Accuracy: 86.46%
# Epoch 8/20 - Train loss: 0.4037, Train accuracy: 86.9792 - Val loss: 0.3558, Val accuracy: 86.4583
# Epoch 8, Loss: 0.3006, Accuracy: 92.71%
# Validation Loss: 0.3225, Accuracy: 86.46%
# Epoch 9/20 - Train loss: 0.3006, Train accuracy: 92.7083 - Val loss: 0.3225, Val accuracy: 86.4583
# Epoch 9, Loss: 0.2972, Accuracy: 90.62%
# Validation Loss: 0.3030, Accuracy: 90.62%
# Epoch 10/20 - Train loss: 0.2972, Train accuracy: 90.6250 - Val loss: 0.3030, Val accuracy: 90.6250
# Epoch 10, Loss: 0.2648, Accuracy: 91.93%
# Validation Loss: 0.3204, Accuracy: 86.46%
# Epoch 11/20 - Train loss: 0.2648, Train accuracy: 91.9271 - Val loss: 0.3204, Val accuracy: 86.4583
# Epoch 11, Loss: 0.2209, Accuracy: 95.31%
# Validation Loss: 0.3506, Accuracy: 87.50%
# Epoch 12/20 - Train loss: 0.2209, Train accuracy: 95.3125 - Val loss: 0.3506, Val accuracy: 87.5000
# Epoch 12, Loss: 0.2557, Accuracy: 91.67%
# Validation Loss: 0.2514, Accuracy: 89.58%
# Epoch 13/20 - Train loss: 0.2557, Train accuracy: 91.6667 - Val loss: 0.2514, Val accuracy: 89.5833
# Epoch 13, Loss: 0.2194, Accuracy: 92.97%
# Validation Loss: 0.2881, Accuracy: 86.46%
# Epoch 14/20 - Train loss: 0.2194, Train accuracy: 92.9688 - Val loss: 0.2881, Val accuracy: 86.4583
# Epoch 14, Loss: 0.2385, Accuracy: 91.93%
# Validation Loss: 0.2084, Accuracy: 91.67%
# Epoch 15/20 - Train loss: 0.2385, Train accuracy: 91.9271 - Val loss: 0.2084, Val accuracy: 91.6667
# Epoch 15, Loss: 0.2309, Accuracy: 91.41%
# Validation Loss: 0.2575, Accuracy: 90.62%
# Epoch 16/20 - Train loss: 0.2309, Train accuracy: 91.4062 - Val loss: 0.2575, Val accuracy: 90.6250
# Epoch 16, Loss: 0.1612, Accuracy: 95.05%
# Validation Loss: 0.2834, Accuracy: 89.58%
# Epoch 17/20 - Train loss: 0.1612, Train accuracy: 95.0521 - Val loss: 0.2834, Val accuracy: 89.5833
# Epoch 17, Loss: 0.1642, Accuracy: 95.05%
# Validation Loss: 0.2786, Accuracy: 90.62%
# Epoch 18/20 - Train loss: 0.1642, Train accuracy: 95.0521 - Val loss: 0.2786, Val accuracy: 90.6250
# Epoch 18, Loss: 0.1496, Accuracy: 96.09%
# Validation Loss: 0.3061, Accuracy: 87.50%
# Epoch 19/20 - Train loss: 0.1496, Train accuracy: 96.0938 - Val loss: 0.3061, Val accuracy: 87.5000
# Epoch 19, Loss: 0.1307, Accuracy: 96.09%
# Validation Loss: 0.2807, Accuracy: 89.58%
# Epoch 20/20 - Train loss: 0.1307, Train accuracy: 96.0938 - Val loss: 0.2807, Val accuracy: 89.5833
# Early stopping!
# Fold 5/5
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/xj/miniconda3/envs/pytorchenv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0, Loss: 1.3007, Accuracy: 38.02%
# Validation Loss: 1.0827, Accuracy: 75.00%
# Epoch 1/20 - Train loss: 1.3007, Train accuracy: 38.0208 - Val loss: 1.0827, Val accuracy: 75.0000
# Epoch 1, Loss: 1.0190, Accuracy: 66.67%
# Validation Loss: 0.7828, Accuracy: 82.29%
# Epoch 2/20 - Train loss: 1.0190, Train accuracy: 66.6667 - Val loss: 0.7828, Val accuracy: 82.2917
# Epoch 2, Loss: 0.8118, Accuracy: 74.48%
# Validation Loss: 0.5983, Accuracy: 84.38%
# Epoch 3/20 - Train loss: 0.8118, Train accuracy: 74.4792 - Val loss: 0.5983, Val accuracy: 84.3750
# Epoch 3, Loss: 0.6716, Accuracy: 79.69%
# Validation Loss: 0.5013, Accuracy: 83.33%
# Epoch 4/20 - Train loss: 0.6716, Train accuracy: 79.6875 - Val loss: 0.5013, Val accuracy: 83.3333
# Epoch 4, Loss: 0.6090, Accuracy: 78.91%
# Validation Loss: 0.4141, Accuracy: 89.58%
# Epoch 5/20 - Train loss: 0.6090, Train accuracy: 78.9062 - Val loss: 0.4141, Val accuracy: 89.5833
# Epoch 5, Loss: 0.5086, Accuracy: 83.33%
# Validation Loss: 0.3677, Accuracy: 91.67%
# Epoch 6/20 - Train loss: 0.5086, Train accuracy: 83.3333 - Val loss: 0.3677, Val accuracy: 91.6667
# Epoch 6, Loss: 0.4521, Accuracy: 84.38%
# Validation Loss: 0.3402, Accuracy: 89.58%
# Epoch 7/20 - Train loss: 0.4521, Train accuracy: 84.3750 - Val loss: 0.3402, Val accuracy: 89.5833
# Epoch 7, Loss: 0.4094, Accuracy: 86.72%
# Validation Loss: 0.2914, Accuracy: 91.67%
# Epoch 8/20 - Train loss: 0.4094, Train accuracy: 86.7188 - Val loss: 0.2914, Val accuracy: 91.6667
# Epoch 8, Loss: 0.3584, Accuracy: 89.32%
# Validation Loss: 0.2491, Accuracy: 93.75%
# Epoch 9/20 - Train loss: 0.3584, Train accuracy: 89.3229 - Val loss: 0.2491, Val accuracy: 93.7500
# Epoch 9, Loss: 0.3616, Accuracy: 88.54%
# Validation Loss: 0.2639, Accuracy: 90.62%
# Epoch 10/20 - Train loss: 0.3616, Train accuracy: 88.5417 - Val loss: 0.2639, Val accuracy: 90.6250
# Epoch 10, Loss: 0.3124, Accuracy: 90.62%
# Validation Loss: 0.2731, Accuracy: 92.71%
# Epoch 11/20 - Train loss: 0.3124, Train accuracy: 90.6250 - Val loss: 0.2731, Val accuracy: 92.7083
# Epoch 11, Loss: 0.2680, Accuracy: 93.23%
# Validation Loss: 0.2650, Accuracy: 90.62%
# Epoch 12/20 - Train loss: 0.2680, Train accuracy: 93.2292 - Val loss: 0.2650, Val accuracy: 90.6250
# Epoch 12, Loss: 0.2111, Accuracy: 94.27%
# Validation Loss: 0.2287, Accuracy: 92.71%
# Epoch 13/20 - Train loss: 0.2111, Train accuracy: 94.2708 - Val loss: 0.2287, Val accuracy: 92.7083
# Epoch 13, Loss: 0.1960, Accuracy: 95.05%
# Validation Loss: 0.2345, Accuracy: 93.75%
# Epoch 14/20 - Train loss: 0.1960, Train accuracy: 95.0521 - Val loss: 0.2345, Val accuracy: 93.7500
# Epoch 14, Loss: 0.1969, Accuracy: 94.79%
# Validation Loss: 0.2170, Accuracy: 91.67%
# Epoch 15/20 - Train loss: 0.1969, Train accuracy: 94.7917 - Val loss: 0.2170, Val accuracy: 91.6667
# Epoch 15, Loss: 0.1752, Accuracy: 94.79%
# Validation Loss: 0.1576, Accuracy: 95.83%
# Epoch 16/20 - Train loss: 0.1752, Train accuracy: 94.7917 - Val loss: 0.1576, Val accuracy: 95.8333
# Epoch 16, Loss: 0.2210, Accuracy: 92.71%
# Validation Loss: 0.1984, Accuracy: 92.71%
# Epoch 17/20 - Train loss: 0.2210, Train accuracy: 92.7083 - Val loss: 0.1984, Val accuracy: 92.7083
# Epoch 17, Loss: 0.1553, Accuracy: 94.53%
# Validation Loss: 0.1718, Accuracy: 94.79%
# Epoch 18/20 - Train loss: 0.1553, Train accuracy: 94.5312 - Val loss: 0.1718, Val accuracy: 94.7917
# Epoch 18, Loss: 0.1609, Accuracy: 96.61%
# Validation Loss: 0.1782, Accuracy: 94.79%
# Epoch 19/20 - Train loss: 0.1609, Train accuracy: 96.6146 - Val loss: 0.1782, Val accuracy: 94.7917
# Epoch 19, Loss: 0.1232, Accuracy: 97.92%
# Validation Loss: 0.2387, Accuracy: 90.62%
# Epoch 20/20 - Train loss: 0.1232, Train accuracy: 97.9167 - Val loss: 0.2387, Val accuracy: 90.6250

# %%
# Plotting results for each fold
for fold_result in fold_results:
    actual_epochs = range(1, len(fold_result['train_losses']) + 1)
    plt.figure(figsize=(18, 6))

    # Plot Training and Validation Loss
    plt.subplot(1, 3, 1)
    plt.plot(actual_epochs, fold_result['train_losses'], 'b', label='Training loss')
    plt.plot(actual_epochs, fold_result['val_losses'], 'r', label='Validation loss')
    plt.title(f'Training and Validation Loss - Fold {fold_result["fold"]}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(actual_epochs, fold_result['train_accuracies'], 'b', label='Training accuracy')
    plt.plot(actual_epochs, fold_result['val_accuracies'], 'r', label='Validation accuracy')
    plt.title(f'Training and Validation Accuracy - Fold {fold_result["fold"]}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot Confusion Matrix
    plt.subplot(1, 3, 3)
    conf_matrix = fold_result['conf_matrix']
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=val_dataset.classes)
    disp.plot(cmap='Blues', ax=plt.gca())
    plt.title(f'Confusion Matrix - Fold {fold_result["fold"]}')
    plt.xlabel('Predicted')
    plt.ylabel('True')

    plt.tight_layout(pad=3.0)
    plt.show()

    # Print classification report for this fold
    print(f'Classification Report for Fold {fold_result["fold"]}:')
    print(classification_report(fold_result['val_true_classes'], fold_result['val_predictions'], target_names=val_dataset.classes))

    # Calculate TP, TN, FP, FN for each class in this fold
    class_names = val_dataset.classes
    table_data = []
    for i, class_name in enumerate(class_names):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - tp - fp - fn
        table_data.append([class_name, tp, tn, fp, fn])

    # Print the TP, TN, FP, FN table for this fold
    print(f"Class-wise TP, TN, FP, FN for Fold {fold_result['fold']}:")
    for row in table_data:
        print(f"Class: {row[0]}, TP: {row[1]}, TN: {row[2]}, FP: {row[3]}, FN: {row[4]}")

    for i, class_auc in enumerate(fold_result['auc_roc']):
        print(f"AUC-ROC for class {val_dataset.classes[i]}: {class_auc:.4f}")

# Calculate mean and variance of validation accuracies across all folds
val_accuracies_all_folds = [result['val_accuracies'][-1] for result in fold_results]  # Take the last epoch's accuracy from each fold
mean_accuracy = np.mean(val_accuracies_all_folds)
variance_accuracy = np.var(val_accuracies_all_folds)

# Display the mean and variance
print(f'Mean Validation Accuracy across all folds: {mean_accuracy:.2f}%')
print(f'Variance of Validation Accuracy across all folds: {variance_accuracy:.2f}%')
# Out:
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#       glioma       0.97      0.89      0.93       510
#   meningioma       0.76      0.75      0.75       425
#      notumor       0.82      0.89      0.86       255
#    pituitary       0.82      0.86      0.84       442
#
#     accuracy                           0.85      1632
#    macro avg       0.84      0.85      0.84      1632
# weighted avg       0.85      0.85      0.85      1632
#
# Class-wise TP, TN, FP, FN for Fold 1:
# Class: glioma, TP: 560, TN: 1324, FP: 16, FN: 20
# Class: meningioma, TP: 313, TN: 1525, FP: 35, FN: 47
# Class: notumor, TP: 438, TN: 1452, FP: 8, FN: 22
# Class: pituitary, TP: 502, TN: 1352, FP: 48, FN: 18
# AUC-ROC for class glioma: 0.9802
# AUC-ROC for class meningioma: 0.8871
# AUC-ROC for class notumor: 0.9805
# AUC-ROC for class pituitary: 0.9500
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#       glioma       0.88      0.92      0.90       320
#   meningioma       0.89      0.72      0.80       520
#      notumor       0.91      0.88      0.89       600
#    pituitary       0.79      0.96      0.86       480
#
#     accuracy                           0.86      1920
#    macro avg       0.87      0.87      0.86      1920
# weighted avg       0.87      0.86      0.86      1920
#
# Class-wise TP, TN, FP, FN for Fold 2:
# Class: glioma, TP: 560, TN: 1324, FP: 16, FN: 20
# Class: meningioma, TP: 313, TN: 1525, FP: 35, FN: 47
# Class: notumor, TP: 438, TN: 1452, FP: 8, FN: 22
# Class: pituitary, TP: 502, TN: 1352, FP: 48, FN: 18
# AUC-ROC for class glioma: 0.9822
# AUC-ROC for class meningioma: 0.9591
# AUC-ROC for class notumor: 0.9747
# AUC-ROC for class pituitary: 0.9829
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#       glioma       0.92      0.89      0.91       460
#   meningioma       0.87      0.70      0.77       560
#      notumor       0.76      0.95      0.84       440
#    pituitary       0.89      0.92      0.91       460
#
#     accuracy                           0.86      1920
#    macro avg       0.86      0.86      0.86      1920
# weighted avg       0.86      0.86      0.85      1920
#
# Class-wise TP, TN, FP, FN for Fold 3:
# Class: glioma, TP: 560, TN: 1324, FP: 16, FN: 20
# Class: meningioma, TP: 313, TN: 1525, FP: 35, FN: 47
# Class: notumor, TP: 438, TN: 1452, FP: 8, FN: 22
# Class: pituitary, TP: 502, TN: 1352, FP: 48, FN: 18
# AUC-ROC for class glioma: 0.9906
# AUC-ROC for class meningioma: 0.9486
# AUC-ROC for class notumor: 0.9787
# AUC-ROC for class pituitary: 0.9847
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#       glioma       0.86      0.97      0.91       440
#   meningioma       0.91      0.68      0.78       460
#      notumor       0.90      0.97      0.94       600
#    pituitary       0.94      0.97      0.96       420
#
#     accuracy                           0.90      1920
#    macro avg       0.90      0.90      0.89      1920
# weighted avg       0.90      0.90      0.90      1920
#
# Class-wise TP, TN, FP, FN for Fold 4:
# Class: glioma, TP: 560, TN: 1324, FP: 16, FN: 20
# Class: meningioma, TP: 313, TN: 1525, FP: 35, FN: 47
# Class: notumor, TP: 438, TN: 1452, FP: 8, FN: 22
# Class: pituitary, TP: 502, TN: 1352, FP: 48, FN: 18
# AUC-ROC for class glioma: 0.9919
# AUC-ROC for class meningioma: 0.9465
# AUC-ROC for class notumor: 0.9878
# AUC-ROC for class pituitary: 0.9972
# Mean Validation Accuracy across all folds: 89.58%
# Variance of Validation Accuracy across all folds: 0.54%

# %%
from PIL import Image
import random

model = SimpleResNet(num_classes=4).to(device)

# Load the model weights
model.load_state_dict(torch.load("resn_saved.pth", map_location=device))
model.eval()

# Define the transformation for the input image
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
])

# Load the dataset using ImageFolder to get the class labels
image_folder = "dataset_13"  # Replace with the path to your image folder
dataset = datasets.ImageFolder(root=image_folder, transform=transform)

# Get the class labels from the dataset
class_labels = dataset.classes

# Function to predict and display a random image from the dataset
def predict_random_image(model, image_folder):
    # Get a list of all class directories
    class_dirs = [d for d in os.listdir(image_folder) if os.path.isdir(os.path.join(image_folder, d))]

    # Choose a random class directory
    random_class = random.choice(class_dirs)
    random_class_dir = os.path.join(image_folder, random_class)

    # Get a list of all images in the chosen class directory
    image_files = [f for f in os.listdir(random_class_dir) if f.endswith(('jpg', 'png', 'jpeg'))]

    # Choose a random image file
    random_image_file = random.choice(image_files)
    random_image_path = os.path.join(random_class_dir, random_image_file)

    # Load and preprocess the image
    img = Image.open(random_image_path)
    img_tensor = transform(img).unsqueeze(0).to(device)
    
    # Make a prediction
    with torch.no_grad():
        output = model(img_tensor)
        _, predicted = torch.max(output, 1)
    
    predicted_label = class_labels[predicted]

    # Display the image with predicted and true labels
    plt.imshow(img)
    plt.title(f"True: {random_class}, Predicted: {predicted_label}")
    plt.axis('off')
    plt.show()

image_folder = "dataset_13" 
predict_random_image(model, image_folder)
